# %% [markdown]
# python intro

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
print("user1")
print("user2")
# Out:
# user1
# user2

# %% [markdown]
# #### Variables

# %%
#variables
#variables are containers used to store data in a program. In Python, you can create a variable by simply assigning a value to a name. For example:
#without variables we cannot store the data and we cannot use it later in the program. Variables are used to store data that can be used and manipulated throughout the program. They allow us to give a name to a value, making it easier to read and understand the code.
a=10
print(a)
# Out:
# 10

# %%
#Datatypes
#In Python, there are several built-in data types that are used to represent different kinds of data. Some of the most commonly used data types in Python include:
#1. Numeric types: int, float, complex
#2. Text type: str
#3. Boolean type: bool
a=10

# %%
#basic datatypes
#1. int: This data type is used to represent whole numbers. For example,
a = 10
print(a)
# Out:
# 10

# %%
#int a=10

# %%
a=10
type(a)
# Out:
# int

# %%
a=12.5

# %%
a=12.5

# %%
a=12.5
print(a)
type(a)
# Out:
# 12.5
# float

# %%
IsAttended=True
type(IsAttended)
print(IsAttended)
# Out:
# True

# %%
a=10
print(a)
print(type(a))
# Out:
# 10
# <class 'int'>

# %%
a=12.5
type()

# %%
text="Hello, World!"
type(text)
print(text)
# Out:
# Hello, World!
